# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b3f02b0b-c0a7-494c-9cde-6e057d5b06c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b3f02b0b-c0a7-494c-9cde-6e057d5b06c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as nm
import statistics as state

# %% [markdown]
# # **Dataset** **Upload**

# %%
df = pd.read_csv("Iris.csv")
df.head(150)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           NaN
# 146  147            6.3           2.5            NaN           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  149 non-null    float64
#  2   SepalWidthCm   149 non-null    float64
#  3   PetalLengthCm  149 non-null    float64
#  4   PetalWidthCm   149 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# # **Checking Null value**

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    1
# SepalWidthCm     1
# PetalLengthCm    1
# PetalWidthCm     1
# Species          0
# dtype: int64

# %% [markdown]
# ## **Placing missing data of SepalLengthCm**

# %%
x = df.SepalLengthCm
x
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
xmean = x.mean()
xmean
# Out:
# 5.83758389261745

# %%
state.median(x)
# Out:
# 5.8

# %%
state.mode(x)
# Out:
# 5.0

# %%
df['SepalLengthCm'].fillna(df['SepalLengthCm'].mean(), inplace = True)

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     1
# PetalLengthCm    1
# PetalWidthCm     1
# Species          0
# dtype: int64

# %% [markdown]
# ## **Placing Missing data of SepalWidthCm**

# %%
y = df.SepalWidthCm
y
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SepalWidthCm, Length: 150, dtype: float64

# %%
ymean = y.mean()
ymean
# Out:
# 3.0523489932885908

# %%
state.median(y)
# Out:
# 3.0

# %%
state.mode(y)
# Out:
# 3.0

# %%
df['SepalWidthCm'].fillna(df['SepalWidthCm'].mean(), inplace = True)

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    1
# PetalWidthCm     1
# Species          0
# dtype: int64

# %% [markdown]
# ## **Placing missing data of PetalLengthCm**

# %%
z = df.PetalLengthCm
z
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    NaN
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PetalLengthCm, Length: 150, dtype: float64

# %%
zmean = z.mean()
zmean
# Out:
# 3.7503355704697983

# %%
state.median(z)
# Out:
# 4.35

# %%
state.mode(z)
# Out:
# 1.5

# %%
df['PetalLengthCm'].fillna(df['PetalLengthCm'].median(), inplace = True)

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     1
# Species          0
# dtype: int64

# %% [markdown]
# ## **Placing missing data of PetalWidthCm**

# %%
w = df.PetalWidthCm
w
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    NaN
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: PetalWidthCm, Length: 150, dtype: float64

# %%
wmean = w.mean()
wmean
# Out:
# 1.191275167785235

# %%
state.median(w)
# Out:
# 1.3

# %%
state.mode(w)
# Out:
# 0.2

# %%
df['PetalWidthCm'].fillna(df['PetalWidthCm'].median(), inplace = True)

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ## **Histogram**

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df['SepalLengthCm'].hist()

# %%
sns.distplot(df['SepalLengthCm'])
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['SepalLengthCm'].skew()
# Out:
# 0.33193212244033155

# %%
df['SepalWidthCm'].hist()

# %%
sns.distplot(df['SepalWidthCm'])
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['SepalWidthCm'].skew()
# Out:
# 0.34548930349769064

# %%
df['PetalLengthCm'].hist()

# %%
sns.distplot(df['PetalLengthCm'])
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['PetalLengthCm'].skew()
# Out:
# -0.2697067431761935

# %%
df['PetalWidthCm'].hist()

# %%
sns.distplot(df['PetalWidthCm'])
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['PetalWidthCm'].skew()
# Out:
# -0.10134352052921512

# %% [markdown]
# ## **Variance**

# %%
print("Variance " , df.SepalLengthCm.var())
# Out:
# Variance  0.6807351020224315

# %%
print("Variance " , df.SepalWidthCm.var())
# Out:
# Variance  0.18759515337146973

# %%
print("Variance " , df.PetalLengthCm.var())
# Out:
# Variance  3.10478255033557

# %%
print("Variance " , df.PetalWidthCm.var())
# Out:
# Variance  0.5742979865771812

# %% [markdown]
# ## **Boxplot and Scatterplot**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'figure.figsize':(5,3), 'figure.dpi':100})

# %%
plt.boxplot(df['SepalLengthCm'],boxprops=dict(color='blue'))
plt.title('Simple Boxplot');

# %%
import seaborn as sns

sns.distplot(df['SepalLengthCm'],hist=True,kde=True,bins=int(180/5),color='darkblue',hist_kws={'edgecolor':'black'},kde_kws={'linewidth':4});
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.scatterplot(data=df['SepalLengthCm'])

# %%
plt.boxplot(df['SepalWidthCm'],boxprops=dict(color='blue'))
plt.title('Simple Boxplot');

# %%
import seaborn as sns

sns.distplot(df['SepalWidthCm'],hist=True,kde=True,bins=int(180/5),color='darkblue',hist_kws={'edgecolor':'black'},kde_kws={'linewidth':4});
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.scatterplot(data=df['SepalWidthCm'])

# %%
plt.boxplot(df['PetalLengthCm'], boxprops=dict(color='blue'))
plt.title('Simple Boxplot');

# %%
import seaborn as sns

sns.distplot(df['PetalLengthCm'],hist=True,kde=True,bins=int(180/5),color='darkblue',hist_kws={'edgecolor':'black'},kde_kws={'linewidth':4});
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.scatterplot(data=df['PetalLengthCm'])

# %%
plt.boxplot(df['PetalWidthCm'], boxprops=dict(color='blue'))
plt.title('Simple Boxplot');

# %%
import seaborn as sns

sns.distplot(df['PetalWidthCm'], hist=True, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4});
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.scatterplot(data=df['PetalWidthCm'])

# %%
g = sns.pairplot(df,hue="Species")
